# %%
from Ratio import *
import numpy as np
from statsmodels.distributions.empirical_distribution import ECDF as fit_ecdf
import scipy.stats as scs
import matplotlib.pyplot as plt

# %%
import numpy as np
# Gaussian copula mixture
N_TRAIN = 2500

# Define means and covariances for 5 Gaussians
mu_1 = -5 * np.ones(2)
sigma_1 = np.array([[1, 0.93], [0.93, 1]])

mu_2 = 5 * np.ones(2)
sigma_2 = np.array([[1, 0.98], [0.98, 1]])

mu_3 = np.array([-5,5])
sigma_3 = np.array([[1, -0.95], [-0.95, 1]])

mu_4 = np.array([5,-5])
sigma_4 = np.array([[1, -0.996], [-0.996, 1]])

size_ = int((N_TRAIN))
x1 = np.random.multivariate_normal(mean=mu_1, cov=sigma_1, size=size_)
x2 = np.random.multivariate_normal(mean=mu_2, cov=sigma_2, size=size_)
x3 = np.random.multivariate_normal(mean=mu_3, cov=sigma_3, size=size_)
x4 = np.random.multivariate_normal(mean=mu_4, cov=sigma_4, size=size_)
X = np.vstack([x1, x2, x3, x4])
np.random.shuffle(X)
plt.scatter(X[:,0],X[:,1],s=1)
plt.show()
# Fit ecdf for marginal distributions
cdf_1 = fit_ecdf(X[:, 0])
cdf_2 = fit_ecdf(X[:, 1])
u_1_mix = cdf_1(X[:, 0])
u_2_mix = cdf_2(X[:, 1])
plt.scatter(u_1_mix,u_2_mix,s=1)
plt.show()

# transform to Gaussian space
data_gaussian = np.stack([scs.norm.ppf(u_1_mix), scs.norm.ppf(u_2_mix)], axis=1)
data_gaussian = np.clip(data_gaussian, -4.5, 4.5)
plt.scatter(data_gaussian[:,0],data_gaussian[:,1],s=1)

# %%
ratio_copula = Ratio(h_dim=100, in_dim=2, h_layers=5, normalising_cst = True, c = 1.0)

# %%
#optimizer = torch.optim.Adam(
#    [{'params': [param for param in ratio_copula.parameters() if param is not ratio_copula.c]},
#     {'params': [ratio_copula.c], 'lr': 0.00001}]  # Adjust the learning rate for ratio.c here)

optimizer = torch.optim.Adam(ratio_copula.parameters(), lr=0.002)
for epoch in range(500):
    optimizer.zero_grad()
    r_p = ratio_copula(torch.tensor(data_gaussian).float())
    r_q = ratio_copula(torch.tensor(scs.norm.rvs(size=(data_gaussian.shape[0],data_gaussian.shape[1]))).float())
    loss = loss_nce(r_p, r_q, data_gaussian.shape[0], data_gaussian.shape[0])
    loss.backward()
    optimizer.step()
    if epoch % 1 == 0 and epoch > 0:
        with torch.no_grad():
             print(f'Epoch {epoch}, loss and normalising constant {loss.item()}', ratio_copula.c.item())
# Out:
# Epoch 1, loss and normalising constant 1.5664772987365723 0.9990039467811584
# Epoch 2, loss and normalising constant 1.3605058193206787 0.9999678134918213
# Epoch 3, loss and normalising constant 1.4118080139160156 1.0001238584518433
# Epoch 4, loss and normalising constant 1.4167234897613525 0.9997382760047913
# Epoch 5, loss and normalising constant 1.3560248613357544 0.999149739742279
# Epoch 6, loss and normalising constant 1.3251588344573975 0.9986411333084106
# Epoch 7, loss and normalising constant 1.3361480236053467 0.9984062910079956
# Epoch 8, loss and normalising constant 1.344338297843933 0.9984691739082336
# Epoch 9, loss and normalising constant 1.3255884647369385 0.9987403750419617
# Epoch 10, loss and normalising constant 1.295821189880371 0.9990884065628052
# Epoch 11, loss and normalising constant 1.2817161083221436 0.9993656277656555
# Epoch 12, loss and normalising constant 1.2795413732528687 0.9994581341743469
# Epoch 13, loss and normalising constant 1.2771767377853394 0.9993383288383484
# Epoch 14, loss and normalising constant 1.2584048509597778 0.9990726709365845
# Epoch 15, loss and normalising constant 1.240401029586792 0.9987722635269165
# Epoch 16, loss and normalising constant 1.2288447618484497 0.9985496997833252
# Epoch 17, loss and normalising constant 1.219878911972046 0.9984651207923889
# Epoch 18, loss and normalising constant 1.206425428390503 0.9984934329986572
# Epoch 19, loss and normalising constant 1.1757361888885498 0.9985518455505371
# Epoch 20, loss and normalising constant 1.1690831184387207 0.99852055311203
# Epoch 21, loss and normalising constant 1.1519098281860352 0.9983627796173096
# Epoch 22, loss and normalising constant 1.1344859600067139 0.9981293678283691
# Epoch 23, loss and normalising constant 1.1206270456314087 0.9979187250137329
# Epoch 24, loss and normalising constant 1.095066785812378 0.9978124499320984
# Epoch 25, loss and normalising constant 1.0821201801300049 0.9977647662162781
# Epoch 26, loss and normalising constant 1.055014967918396 0.9976791143417358
# Epoch 27, loss and normalising constant 1.0409663915634155 0.9974960088729858
# Epoch 28, loss and normalising constant 1.0208114385604858 0.9972858428955078
# Epoch 29, loss and normalising constant 1.0058269500732422 0.997160792350769
# Epoch 30, loss and normalising constant 0.9912543296813965 0.9971312880516052
# Epoch 31, loss and normalising constant 0.9677733182907104 0.9970945119857788
# Epoch 32, loss and normalising constant 0.9528648853302002 0.9969915747642517
# Epoch 33, loss and normalising constant 0.9341682195663452 0.9968995451927185
# Epoch 34, loss and normalising constant 0.9245979189872742 0.9968839287757874
# Epoch 35, loss and normalising constant 0.8921458721160889 0.9968750476837158
# Epoch 36, loss and normalising constant 0.8986022472381592 0.996795654296875
# Epoch 37, loss and normalising constant 0.8785480856895447 0.9967902898788452
# Epoch 38, loss and normalising constant 0.8642556667327881 0.9968256950378418
# Epoch 39, loss and normalising constant 0.8568316102027893 0.9967748522758484
# Epoch 40, loss and normalising constant 0.8488444089889526 0.9967527389526367
# Epoch 41, loss and normalising constant 0.8401459455490112 0.9968031048774719
# Epoch 42, loss and normalising constant 0.8322375416755676 0.9967719316482544
# Epoch 43, loss and normalising constant 0.822799563407898 0.9967342615127563
# Epoch 44, loss and normalising constant 0.8177330493927002 0.9968437552452087
# Epoch 45, loss and normalising constant 0.8075269460678101 0.9968591928482056
# Epoch 46, loss and normalising constant 0.7944736480712891 0.996883749961853
# Epoch 47, loss and normalising constant 0.7968045473098755 0.9970118403434753
# Epoch 48, loss and normalising constant 0.786461353302002 0.9970223307609558
# Epoch 49, loss and normalising constant 0.7762972116470337 0.9970428347587585
# Epoch 50, loss and normalising constant 0.7842788696289062 0.9971849322319031
# Epoch 51, loss and normalising constant 0.7745907306671143 0.9971858263015747
# Epoch 52, loss and normalising constant 0.7554342150688171 0.9972513318061829
# Epoch 53, loss and normalising constant 0.7583228945732117 0.997384250164032
# Epoch 54, loss and normalising constant 0.7628469467163086 0.9973699450492859
# Epoch 55, loss and normalising constant 0.7528063058853149 0.9974576234817505
# Epoch 56, loss and normalising constant 0.7440855503082275 0.9975287318229675
# Epoch 57, loss and normalising constant 0.7467166781425476 0.9975333213806152
# Epoch 58, loss and normalising constant 0.7382459044456482 0.997672975063324
# Epoch 59, loss and normalising constant 0.7468695640563965 0.9976813197135925
# Epoch 60, loss and normalising constant 0.732369601726532 0.9977121353149414
# Epoch 61, loss and normalising constant 0.734012246131897 0.997828483581543
# Epoch 62, loss and normalising constant 0.739689826965332 0.9978063702583313
# Epoch 63, loss and normalising constant 0.7213615775108337 0.9978967905044556
# Epoch 64, loss and normalising constant 0.7189573049545288 0.997978925704956
# Epoch 65, loss and normalising constant 0.7208613753318787 0.9979571104049683
# Epoch 66, loss and normalising constant 0.7311319708824158 0.9980074167251587
# Epoch 67, loss and normalising constant 0.7271816730499268 0.9980063438415527
# Epoch 68, loss and normalising constant 0.7255101203918457 0.997992753982544
# Epoch 69, loss and normalising constant 0.7267479300498962 0.9980700016021729
# Epoch 70, loss and normalising constant 0.7185173034667969 0.9980209469795227
# Epoch 71, loss and normalising constant 0.7251200079917908 0.9980475902557373
# Epoch 72, loss and normalising constant 0.7197868824005127 0.99809330701828
# Epoch 73, loss and normalising constant 0.7132434844970703 0.9980879426002502
# Epoch 74, loss and normalising constant 0.7195885181427002 0.9981904625892639
# Epoch 75, loss and normalising constant 0.7233259677886963 0.9981195330619812
# Epoch 76, loss and normalising constant 0.7170392274856567 0.998224675655365
# Epoch 77, loss and normalising constant 0.7191191911697388 0.9982029795646667
# Epoch 78, loss and normalising constant 0.7235797047615051 0.9981927871704102
# Epoch 79, loss and normalising constant 0.7135639786720276 0.9982828497886658
# Epoch 80, loss and normalising constant 0.7184616923332214 0.9982044100761414
# Epoch 81, loss and normalising constant 0.7144691348075867 0.9982729554176331
# Epoch 82, loss and normalising constant 0.7041536569595337 0.9982684850692749
# Epoch 83, loss and normalising constant 0.7037774324417114 0.9982386231422424
# Epoch 84, loss and normalising constant 0.7173237204551697 0.9983320832252502
# Epoch 85, loss and normalising constant 0.7302332520484924 0.9982312917709351
# Epoch 86, loss and normalising constant 0.724309504032135 0.9983163475990295
# Epoch 87, loss and normalising constant 0.7108228802680969 0.9983721375465393
# Epoch 88, loss and normalising constant 0.7172074317932129 0.9982884526252747
# Epoch 89, loss and normalising constant 0.7412078380584717 0.9984251260757446
# Epoch 90, loss and normalising constant 0.7226830124855042 0.9983881711959839
# Epoch 91, loss and normalising constant 0.710009753704071 0.9983903169631958
# Epoch 92, loss and normalising constant 0.700729250907898 0.998443067073822
# Epoch 93, loss and normalising constant 0.7106376886367798 0.998446524143219
# Epoch 94, loss and normalising constant 0.7079626321792603 0.9984607696533203
# Epoch 95, loss and normalising constant 0.6954673528671265 0.9984906911849976
# Epoch 96, loss and normalising constant 0.6947668790817261 0.9985172748565674
# Epoch 97, loss and normalising constant 0.6927351951599121 0.9985488057136536
# Epoch 98, loss and normalising constant 0.7105281352996826 0.9985688924789429
# Epoch 99, loss and normalising constant 0.692280650138855 0.9985997676849365
# Epoch 100, loss and normalising constant 0.6985870599746704 0.998609721660614
# Epoch 101, loss and normalising constant 0.6959604620933533 0.998625636100769
# Epoch 102, loss and normalising constant 0.6965615749359131 0.9986608624458313
# Epoch 103, loss and normalising constant 0.7017859220504761 0.9986388683319092
# Epoch 104, loss and normalising constant 0.7013213038444519 0.9986916780471802
# Epoch 105, loss and normalising constant 0.7031532526016235 0.9987287521362305
# Epoch 106, loss and normalising constant 0.692431628704071 0.9987053871154785
# Epoch 107, loss and normalising constant 0.6966395974159241 0.998735785484314
# Epoch 108, loss and normalising constant 0.6983002424240112 0.9987782835960388
# Epoch 109, loss and normalising constant 0.6887654066085815 0.9987888932228088
# Epoch 110, loss and normalising constant 0.6914470791816711 0.9987791776657104
# Epoch 111, loss and normalising constant 0.7036912441253662 0.9988219738006592
# Epoch 112, loss and normalising constant 0.7028589248657227 0.9988325238227844
# Epoch 113, loss and normalising constant 0.7010309100151062 0.9988223314285278
# Epoch 114, loss and normalising constant 0.6975548267364502 0.9988149404525757
# Epoch 115, loss and normalising constant 0.6870522499084473 0.9988405704498291
# Epoch 116, loss and normalising constant 0.6905322074890137 0.9987825751304626
# Epoch 117, loss and normalising constant 0.6979896426200867 0.9988555312156677
# Epoch 118, loss and normalising constant 0.6998556852340698 0.9987805485725403
# Epoch 119, loss and normalising constant 0.7024350166320801 0.9988270998001099
# Epoch 120, loss and normalising constant 0.6884185075759888 0.9988847970962524
# Epoch 121, loss and normalising constant 0.6904420256614685 0.9988018274307251
# Epoch 122, loss and normalising constant 0.7010048031806946 0.9989102482795715
# Epoch 123, loss and normalising constant 0.7009139060974121 0.9988935589790344
# Epoch 124, loss and normalising constant 0.6909202337265015 0.9988850355148315
# Epoch 125, loss and normalising constant 0.6919789910316467 0.9989495873451233
# Epoch 126, loss and normalising constant 0.6970736980438232 0.9989031553268433
# Epoch 127, loss and normalising constant 0.6973928213119507 0.9990035891532898
# Epoch 128, loss and normalising constant 0.7007045149803162 0.9989099502563477
# Epoch 129, loss and normalising constant 0.6940184831619263 0.9989399313926697
# Epoch 130, loss and normalising constant 0.6927231550216675 0.9989679455757141
# Epoch 131, loss and normalising constant 0.6830047369003296 0.9988702535629272
# Epoch 132, loss and normalising constant 0.6957408785820007 0.9988939762115479
# Epoch 133, loss and normalising constant 0.6830248832702637 0.9989479184150696
# Epoch 134, loss and normalising constant 0.7108520269393921 0.9988519549369812
# Epoch 135, loss and normalising constant 0.6946378350257874 0.9989473819732666
# Epoch 136, loss and normalising constant 0.7114373445510864 0.9988765716552734
# Epoch 137, loss and normalising constant 0.6773452162742615 0.9989067912101746
# Epoch 138, loss and normalising constant 0.6872053742408752 0.9989641308784485
# Epoch 139, loss and normalising constant 0.687768816947937 0.9988974928855896
# Epoch 140, loss and normalising constant 0.6908715963363647 0.9989385604858398
# Epoch 141, loss and normalising constant 0.6865336298942566 0.9990047216415405
# Epoch 142, loss and normalising constant 0.6964281797409058 0.998952329158783
# Epoch 143, loss and normalising constant 0.6868064403533936 0.9990246295928955
# Epoch 144, loss and normalising constant 0.6944707632064819 0.9990231394767761
# Epoch 145, loss and normalising constant 0.7050777077674866 0.9990114569664001
# Epoch 146, loss and normalising constant 0.6923079490661621 0.9990792274475098
# Epoch 147, loss and normalising constant 0.6856644153594971 0.9990658164024353
# Epoch 148, loss and normalising constant 0.6859273910522461 0.9990268349647522
# Epoch 149, loss and normalising constant 0.7073581218719482 0.9990696310997009
# Epoch 150, loss and normalising constant 0.687527060508728 0.9990567564964294
# Epoch 151, loss and normalising constant 0.6803902387619019 0.9990187287330627
# Epoch 152, loss and normalising constant 0.6873188018798828 0.9990949034690857
# Epoch 153, loss and normalising constant 0.7036643028259277 0.9990101456642151
# Epoch 154, loss and normalising constant 0.6895132064819336 0.9990939497947693
# Epoch 155, loss and normalising constant 0.6794164180755615 0.9991454482078552
# Epoch 156, loss and normalising constant 0.6950368881225586 0.9990566968917847
# Epoch 157, loss and normalising constant 0.70557701587677 0.9991863965988159
# Epoch 158, loss and normalising constant 0.6932502388954163 0.9991418123245239
# Epoch 159, loss and normalising constant 0.6866781115531921 0.9991201162338257
# Epoch 160, loss and normalising constant 0.6885526776313782 0.999182939529419
# Epoch 161, loss and normalising constant 0.6950466632843018 0.9991217255592346
# Epoch 162, loss and normalising constant 0.6918752789497375 0.9991465210914612
# Epoch 163, loss and normalising constant 0.7032397389411926 0.9991973638534546
# Epoch 164, loss and normalising constant 0.6779097318649292 0.9991573095321655
# Epoch 165, loss and normalising constant 0.6827372312545776 0.9991455674171448
# Epoch 166, loss and normalising constant 0.6921285390853882 0.9992040991783142
# Epoch 167, loss and normalising constant 0.6759992837905884 0.999222457408905
# Epoch 168, loss and normalising constant 0.6820849180221558 0.9991558790206909
# Epoch 169, loss and normalising constant 0.6898632049560547 0.9992752075195312
# Epoch 170, loss and normalising constant 0.6729214787483215 0.9993016123771667
# Epoch 171, loss and normalising constant 0.6888159513473511 0.9992257356643677
# Epoch 172, loss and normalising constant 0.6913622617721558 0.9993794560432434
# Epoch 173, loss and normalising constant 0.708865761756897 0.9992658495903015
# Epoch 174, loss and normalising constant 0.7010650634765625 0.9992924332618713
# Epoch 175, loss and normalising constant 0.6835571527481079 0.9994228482246399
# Epoch 176, loss and normalising constant 0.7100042104721069 0.9992837905883789
# Epoch 177, loss and normalising constant 0.703569769859314 0.9993756413459778
# Epoch 178, loss and normalising constant 0.6981649994850159 0.9993834495544434
# Epoch 179, loss and normalising constant 0.6918801069259644 0.9993222951889038
# Epoch 180, loss and normalising constant 0.6949098110198975 0.9994792938232422
# Epoch 181, loss and normalising constant 0.69448322057724 0.999387264251709
# Epoch 182, loss and normalising constant 0.6763104200363159 0.9993327856063843
# Epoch 183, loss and normalising constant 0.6864516139030457 0.9994984865188599
# Epoch 184, loss and normalising constant 0.7020857334136963 0.9993800520896912
# Epoch 185, loss and normalising constant 0.6912678480148315 0.9993182420730591
# Epoch 186, loss and normalising constant 0.6940183639526367 0.9995163083076477
# Epoch 187, loss and normalising constant 0.7252878546714783 0.9993689060211182
# Epoch 188, loss and normalising constant 0.6769615411758423 0.99936443567276
# Epoch 189, loss and normalising constant 0.6839573383331299 0.9995226263999939
# Epoch 190, loss and normalising constant 0.7094411253929138 0.9994165301322937
# Epoch 191, loss and normalising constant 0.6844048500061035 0.9994279146194458
# Epoch 192, loss and normalising constant 0.6884057521820068 0.9995283484458923
# Epoch 193, loss and normalising constant 0.6818224787712097 0.9995179772377014
# Epoch 194, loss and normalising constant 0.6814718246459961 0.9994878768920898
# Epoch 195, loss and normalising constant 0.6981887817382812 0.9995928406715393
# Epoch 196, loss and normalising constant 0.6846200227737427 0.9996019005775452
# Epoch 197, loss and normalising constant 0.6865749359130859 0.9995214343070984
# Epoch 198, loss and normalising constant 0.6765937805175781 0.9996181726455688
# Epoch 199, loss and normalising constant 0.6892499327659607 0.9996357560157776
# Epoch 200, loss and normalising constant 0.6747459173202515 0.9996222853660583
# Epoch 201, loss and normalising constant 0.6952496767044067 0.9996404051780701
# Epoch 202, loss and normalising constant 0.6848655939102173 0.9997101426124573
# Epoch 203, loss and normalising constant 0.6787227392196655 0.9997064471244812
# Epoch 204, loss and normalising constant 0.6804764866828918 0.9996859431266785
# Epoch 205, loss and normalising constant 0.6845332384109497 0.9997581839561462
# Epoch 206, loss and normalising constant 0.6813939809799194 0.9997699856758118
# Epoch 207, loss and normalising constant 0.6868948936462402 0.9997349381446838
# Epoch 208, loss and normalising constant 0.6904561519622803 0.9998103380203247
# Epoch 209, loss and normalising constant 0.6835250854492188 0.9998207688331604
# Epoch 210, loss and normalising constant 0.6811249256134033 0.9997948408126831
# Epoch 211, loss and normalising constant 0.6957088708877563 0.9998630881309509
# Epoch 212, loss and normalising constant 0.6852371692657471 0.9998773336410522
# Epoch 213, loss and normalising constant 0.6937141418457031 0.999815046787262
# Epoch 214, loss and normalising constant 0.6688613891601562 0.9999188184738159
# Epoch 215, loss and normalising constant 0.6715843677520752 0.9999052882194519
# Epoch 216, loss and normalising constant 0.6779134273529053 0.9998512864112854
# Epoch 217, loss and normalising constant 0.6904374361038208 0.9999633431434631
# Epoch 218, loss and normalising constant 0.6834227442741394 0.9999330639839172
# Epoch 219, loss and normalising constant 0.6761447191238403 0.9999237060546875
# Epoch 220, loss and normalising constant 0.6822550296783447 1.000015377998352
# Epoch 221, loss and normalising constant 0.6915958523750305 0.9999882578849792
# Epoch 222, loss and normalising constant 0.6826502084732056 0.9999756813049316
# Epoch 223, loss and normalising constant 0.6802541017532349 0.9999962449073792
# Epoch 224, loss and normalising constant 0.6898983716964722 0.9999645352363586
# Epoch 225, loss and normalising constant 0.6750636100769043 0.999984085559845
# Epoch 226, loss and normalising constant 0.681094765663147 1.0000063180923462
# Epoch 227, loss and normalising constant 0.6802984476089478 0.9999650120735168
# Epoch 228, loss and normalising constant 0.6832807064056396 0.999981164932251
# Epoch 229, loss and normalising constant 0.6700814962387085 1.0000333786010742
# Epoch 230, loss and normalising constant 0.6861563920974731 0.9999828338623047
# Epoch 231, loss and normalising constant 0.6846367120742798 1.0000641345977783
# Epoch 232, loss and normalising constant 0.6970657706260681 1.0000160932540894
# Epoch 233, loss and normalising constant 0.6844209432601929 1.0000535249710083
# Epoch 234, loss and normalising constant 0.6802770495414734 1.0001294612884521
# Epoch 235, loss and normalising constant 0.6758442521095276 1.000105619430542
# Epoch 236, loss and normalising constant 0.6838464736938477 1.000063419342041
# Epoch 237, loss and normalising constant 0.6730839014053345 1.0001473426818848
# Epoch 238, loss and normalising constant 0.6811771392822266 1.0000886917114258
# Epoch 239, loss and normalising constant 0.6894105672836304 1.0000871419906616
# Epoch 240, loss and normalising constant 0.6920472383499146 1.0001897811889648
# Epoch 241, loss and normalising constant 0.676659882068634 1.000141978263855
# Epoch 242, loss and normalising constant 0.6700218915939331 1.0001275539398193
# Epoch 243, loss and normalising constant 0.6777967810630798 1.0002217292785645
# Epoch 244, loss and normalising constant 0.6798900365829468 1.0001990795135498
# Epoch 245, loss and normalising constant 0.671862006187439 1.0002098083496094
# Epoch 246, loss and normalising constant 0.6796578168869019 1.0002573728561401
# Epoch 247, loss and normalising constant 0.683579683303833 1.0002355575561523
# Epoch 248, loss and normalising constant 0.6759113073348999 1.0002763271331787
# Epoch 249, loss and normalising constant 0.6853307485580444 1.000276803970337
# Epoch 250, loss and normalising constant 0.678583025932312 1.0002518892288208
# Epoch 251, loss and normalising constant 0.670344352722168 1.000296711921692
# Epoch 252, loss and normalising constant 0.6893279552459717 1.0002707242965698
# Epoch 253, loss and normalising constant 0.6752018928527832 1.000374674797058
# Epoch 254, loss and normalising constant 0.6935164928436279 1.000319480895996
# Epoch 255, loss and normalising constant 0.6769624352455139 1.000359296798706
# Epoch 256, loss and normalising constant 0.6850106716156006 1.0003730058670044
# Epoch 257, loss and normalising constant 0.6708722114562988 1.0003814697265625
# Epoch 258, loss and normalising constant 0.684561014175415 1.0003273487091064
# Epoch 259, loss and normalising constant 0.6807447671890259 1.000320315361023
# Epoch 260, loss and normalising constant 0.6805623173713684 1.0003106594085693
# Epoch 261, loss and normalising constant 0.6642265915870667 1.00033700466156
# Epoch 262, loss and normalising constant 0.6875631809234619 1.0003005266189575
# Epoch 263, loss and normalising constant 0.6847367882728577 1.000285267829895
# Epoch 264, loss and normalising constant 0.6820904016494751 1.0003217458724976
# Epoch 265, loss and normalising constant 0.6804593205451965 1.0002986192703247
# Epoch 266, loss and normalising constant 0.6950688362121582 1.0003278255462646
# Epoch 267, loss and normalising constant 0.6687939167022705 1.0002790689468384
# Epoch 268, loss and normalising constant 0.6846221685409546 1.0002598762512207
# Epoch 269, loss and normalising constant 0.6804589033126831 1.0004085302352905
# Epoch 270, loss and normalising constant 0.6936038732528687 1.0003330707550049
# Epoch 271, loss and normalising constant 0.6908260583877563 1.0004148483276367
# Epoch 272, loss and normalising constant 0.6806875467300415 1.0004334449768066
# Epoch 273, loss and normalising constant 0.6809744238853455 1.000438928604126
# Epoch 274, loss and normalising constant 0.6744080781936646 1.0005764961242676
# Epoch 275, loss and normalising constant 0.6891156435012817 1.0004892349243164
# Epoch 276, loss and normalising constant 0.6839368343353271 1.0005031824111938
# Epoch 277, loss and normalising constant 0.6764377355575562 1.000556468963623
# Epoch 278, loss and normalising constant 0.6720432639122009 1.0004732608795166
# Epoch 279, loss and normalising constant 0.6801027059555054 1.0005319118499756
# Epoch 280, loss and normalising constant 0.6718490123748779 1.0004810094833374
# Epoch 281, loss and normalising constant 0.6763932704925537 1.000461459159851
# Epoch 282, loss and normalising constant 0.6780975461006165 1.0005908012390137
# Epoch 283, loss and normalising constant 0.6905547380447388 1.0005091428756714
# Epoch 284, loss and normalising constant 0.6821889877319336 1.0005309581756592
# Epoch 285, loss and normalising constant 0.6771156191825867 1.0005978345870972
# Epoch 286, loss and normalising constant 0.6745429039001465 1.0005477666854858
# Epoch 287, loss and normalising constant 0.6824196577072144 1.000629186630249
# Epoch 288, loss and normalising constant 0.6843210458755493 1.000578761100769
# Epoch 289, loss and normalising constant 0.6775717735290527 1.0005381107330322
# Epoch 290, loss and normalising constant 0.6834554672241211 1.0006561279296875
# Epoch 291, loss and normalising constant 0.684251070022583 1.0005700588226318
# Epoch 292, loss and normalising constant 0.676478922367096 1.0006073713302612
# Epoch 293, loss and normalising constant 0.6740649342536926 1.0006216764450073
# Epoch 294, loss and normalising constant 0.6693535447120667 1.0006040334701538
# Epoch 295, loss and normalising constant 0.6727845668792725 1.0006464719772339
# Epoch 296, loss and normalising constant 0.6756049394607544 1.0007082223892212
# Epoch 297, loss and normalising constant 0.6787495613098145 1.0006475448608398
# Epoch 298, loss and normalising constant 0.6766616702079773 1.0007025003433228
# Epoch 299, loss and normalising constant 0.6788114309310913 1.0006908178329468
# Epoch 300, loss and normalising constant 0.6825783252716064 1.0006660223007202
# Epoch 301, loss and normalising constant 0.696480929851532 1.0006698369979858
# Epoch 302, loss and normalising constant 0.6762871742248535 1.0007070302963257
# Epoch 303, loss and normalising constant 0.671257495880127 1.0006871223449707
# Epoch 304, loss and normalising constant 0.6874799728393555 1.0007158517837524
# Epoch 305, loss and normalising constant 0.6774808764457703 1.000778317451477
# Epoch 306, loss and normalising constant 0.6789911985397339 1.0007319450378418
# Epoch 307, loss and normalising constant 0.6801074743270874 1.0008368492126465
# Epoch 308, loss and normalising constant 0.6752628087997437 1.0008143186569214
# Epoch 309, loss and normalising constant 0.6813687086105347 1.0007691383361816
# Epoch 310, loss and normalising constant 0.675705075263977 1.000887393951416
# Epoch 311, loss and normalising constant 0.6909241676330566 1.0007283687591553
# Epoch 312, loss and normalising constant 0.6809736490249634 1.0008498430252075
# Epoch 313, loss and normalising constant 0.6896824836730957 1.0008149147033691
# Epoch 314, loss and normalising constant 0.6868515610694885 1.0007600784301758
# Epoch 315, loss and normalising constant 0.6987909078598022 1.0009188652038574
# Epoch 316, loss and normalising constant 0.711370587348938 1.0007522106170654
# Epoch 317, loss and normalising constant 0.6860055923461914 1.0008805990219116
# Epoch 318, loss and normalising constant 0.6887751817703247 1.000911831855774
# Epoch 319, loss and normalising constant 0.6850544214248657 1.0007821321487427
# Epoch 320, loss and normalising constant 0.7047199010848999 1.0009946823120117
# Epoch 321, loss and normalising constant 0.6855595111846924 1.0009088516235352
# Epoch 322, loss and normalising constant 0.6870035529136658 1.0007977485656738
# Epoch 323, loss and normalising constant 0.6912964582443237 1.0010814666748047
# Epoch 324, loss and normalising constant 0.7111954092979431 1.0009247064590454
# Epoch 325, loss and normalising constant 0.6741752624511719 1.0007771253585815
# Epoch 326, loss and normalising constant 0.7193785905838013 1.0011131763458252
# Epoch 327, loss and normalising constant 0.730061948299408 1.000981092453003
# Epoch 328, loss and normalising constant 0.6976546049118042 1.0007745027542114
# Epoch 329, loss and normalising constant 0.7233644723892212 1.0011283159255981
# Epoch 330, loss and normalising constant 0.7219570875167847 1.0010292530059814
# Epoch 331, loss and normalising constant 0.692663311958313 1.0007946491241455
# Epoch 332, loss and normalising constant 0.732397198677063 1.0011028051376343
# Epoch 333, loss and normalising constant 0.7098495364189148 1.0011717081069946
# Epoch 334, loss and normalising constant 0.7025722861289978 1.0009539127349854
# Epoch 335, loss and normalising constant 0.6978970170021057 1.001092791557312
# Epoch 336, loss and normalising constant 0.6897383332252502 1.00132417678833
# Epoch 337, loss and normalising constant 0.7056972980499268 1.0012643337249756
# Epoch 338, loss and normalising constant 0.6970665454864502 1.0011811256408691
# Epoch 339, loss and normalising constant 0.683946967124939 1.0013679265975952
# Epoch 340, loss and normalising constant 0.6836175918579102 1.001480221748352
# Epoch 341, loss and normalising constant 0.6972625255584717 1.0013573169708252
# Epoch 342, loss and normalising constant 0.6900161504745483 1.0013885498046875
# Epoch 343, loss and normalising constant 0.6797102093696594 1.0015389919281006
# Epoch 344, loss and normalising constant 0.6947826147079468 1.0015604496002197
# Epoch 345, loss and normalising constant 0.6828017830848694 1.0014938116073608
# Epoch 346, loss and normalising constant 0.680200457572937 1.001581072807312
# Epoch 347, loss and normalising constant 0.6794406175613403 1.0016909837722778
# Epoch 348, loss and normalising constant 0.6729627251625061 1.0016931295394897
# Epoch 349, loss and normalising constant 0.6827869415283203 1.0016701221466064
# Epoch 350, loss and normalising constant 0.6772692203521729 1.001802921295166
# Epoch 351, loss and normalising constant 0.6855575442314148 1.001871943473816
# Epoch 352, loss and normalising constant 0.6697503924369812 1.001844048500061
# Epoch 353, loss and normalising constant 0.68279629945755 1.0018298625946045
# Epoch 354, loss and normalising constant 0.677190363407135 1.0019333362579346
# Epoch 355, loss and normalising constant 0.6805896759033203 1.001970648765564
# Epoch 356, loss and normalising constant 0.6686174869537354 1.001938819885254
# Epoch 357, loss and normalising constant 0.6750688552856445 1.0019294023513794
# Epoch 358, loss and normalising constant 0.6803338527679443 1.0019806623458862
# Epoch 359, loss and normalising constant 0.6809297800064087 1.0019668340682983
# Epoch 360, loss and normalising constant 0.6715302467346191 1.0019745826721191
# Epoch 361, loss and normalising constant 0.6759318113327026 1.0019868612289429
# Epoch 362, loss and normalising constant 0.6741862297058105 1.0019968748092651
# Epoch 363, loss and normalising constant 0.671866238117218 1.001983404159546
# Epoch 364, loss and normalising constant 0.6855449676513672 1.0019670724868774
# Epoch 365, loss and normalising constant 0.6802175641059875 1.0019985437393188
# Epoch 366, loss and normalising constant 0.6711289286613464 1.0020196437835693
# Epoch 367, loss and normalising constant 0.6841943264007568 1.0019888877868652
# Epoch 368, loss and normalising constant 0.6728758811950684 1.0020161867141724
# Epoch 369, loss and normalising constant 0.677340030670166 1.0020513534545898
# Epoch 370, loss and normalising constant 0.6699566841125488 1.002045750617981
# Epoch 371, loss and normalising constant 0.6749635934829712 1.0020418167114258
# Epoch 372, loss and normalising constant 0.6741975545883179 1.0020912885665894
# Epoch 373, loss and normalising constant 0.6806671619415283 1.0021308660507202
# Epoch 374, loss and normalising constant 0.6700977087020874 1.0021607875823975
# Epoch 375, loss and normalising constant 0.6687617301940918 1.0021662712097168
# Epoch 376, loss and normalising constant 0.672034740447998 1.0021854639053345
# Epoch 377, loss and normalising constant 0.6806149482727051 1.0021936893463135
# Epoch 378, loss and normalising constant 0.6872345209121704 1.002195119857788
# Epoch 379, loss and normalising constant 0.6771851181983948 1.0022143125534058
# Epoch 380, loss and normalising constant 0.6840747594833374 1.0022032260894775
# Epoch 381, loss and normalising constant 0.6831399202346802 1.0021960735321045
# Epoch 382, loss and normalising constant 0.6667216420173645 1.002260684967041
# Epoch 383, loss and normalising constant 0.6785647869110107 1.002233862876892
# Epoch 384, loss and normalising constant 0.6671354174613953 1.0022233724594116
# Epoch 385, loss and normalising constant 0.6885740756988525 1.002219319343567
# Epoch 386, loss and normalising constant 0.6808514595031738 1.0022310018539429
# Epoch 387, loss and normalising constant 0.6635960340499878 1.0022711753845215
# Epoch 388, loss and normalising constant 0.6751299500465393 1.0022244453430176
# Epoch 389, loss and normalising constant 0.6800429821014404 1.0022090673446655
# Epoch 390, loss and normalising constant 0.6783621311187744 1.0022525787353516
# Epoch 391, loss and normalising constant 0.6871969103813171 1.0022097826004028
# Epoch 392, loss and normalising constant 0.6652337312698364 1.0022103786468506
# Epoch 393, loss and normalising constant 0.6672343611717224 1.002207636833191
# Epoch 394, loss and normalising constant 0.6742815971374512 1.0021989345550537
# Epoch 395, loss and normalising constant 0.6803028583526611 1.0022077560424805
# Epoch 396, loss and normalising constant 0.6803674697875977 1.0022242069244385
# Epoch 397, loss and normalising constant 0.6723266839981079 1.002230167388916
# Epoch 398, loss and normalising constant 0.6745140552520752 1.002241849899292
# Epoch 399, loss and normalising constant 0.6806768178939819 1.0022653341293335
# Epoch 400, loss and normalising constant 0.670820951461792 1.0022886991500854
# Epoch 401, loss and normalising constant 0.6795709133148193 1.0022718906402588
# Epoch 402, loss and normalising constant 0.6697105169296265 1.0022945404052734
# Epoch 403, loss and normalising constant 0.6699886322021484 1.002301812171936
# Epoch 404, loss and normalising constant 0.676826000213623 1.0022913217544556
# Epoch 405, loss and normalising constant 0.6768769025802612 1.0023137331008911
# Epoch 406, loss and normalising constant 0.6712061166763306 1.0023146867752075
# Epoch 407, loss and normalising constant 0.6817024946212769 1.002242088317871
# Epoch 408, loss and normalising constant 0.6770352721214294 1.002287745475769
# Epoch 409, loss and normalising constant 0.6780164241790771 1.002315640449524
# Epoch 410, loss and normalising constant 0.6866765022277832 1.0022130012512207
# Epoch 411, loss and normalising constant 0.6740999221801758 1.0022081136703491
# Epoch 412, loss and normalising constant 0.6888630986213684 1.0022070407867432
# Epoch 413, loss and normalising constant 0.679348349571228 1.002203345298767
# Epoch 414, loss and normalising constant 0.6718682050704956 1.002238392829895
# Epoch 415, loss and normalising constant 0.6666840314865112 1.002206563949585
# Epoch 416, loss and normalising constant 0.6858013272285461 1.0021886825561523
# Epoch 417, loss and normalising constant 0.6735410094261169 1.0022872686386108
# Epoch 418, loss and normalising constant 0.6872352957725525 1.0022826194763184
# Epoch 419, loss and normalising constant 0.671012282371521 1.0022631883621216
# Epoch 420, loss and normalising constant 0.6665096282958984 1.0023245811462402
# Epoch 421, loss and normalising constant 0.6831647157669067 1.0023117065429688
# Epoch 422, loss and normalising constant 0.6778722405433655 1.0023125410079956
# Epoch 423, loss and normalising constant 0.68583083152771 1.0023425817489624
# Epoch 424, loss and normalising constant 0.6747829914093018 1.0023658275604248
# Epoch 425, loss and normalising constant 0.6825726628303528 1.002300500869751
# Epoch 426, loss and normalising constant 0.6779420971870422 1.0023475885391235
# Epoch 427, loss and normalising constant 0.6850922107696533 1.002366542816162
# Epoch 428, loss and normalising constant 0.679491400718689 1.002364158630371
# Epoch 429, loss and normalising constant 0.6794719099998474 1.0024186372756958
# Epoch 430, loss and normalising constant 0.6741625070571899 1.0024000406265259
# Epoch 431, loss and normalising constant 0.6793334484100342 1.002378225326538
# Epoch 432, loss and normalising constant 0.6723432540893555 1.0024659633636475
# Epoch 433, loss and normalising constant 0.6784042119979858 1.0024358034133911
# Epoch 434, loss and normalising constant 0.6785522699356079 1.0023552179336548
# Epoch 435, loss and normalising constant 0.674750566482544 1.0024677515029907
# Epoch 436, loss and normalising constant 0.6696773767471313 1.0024558305740356
# Epoch 437, loss and normalising constant 0.6865638494491577 1.002337098121643
# Epoch 438, loss and normalising constant 0.6794098019599915 1.0024484395980835
# Epoch 439, loss and normalising constant 0.6655133366584778 1.0024694204330444
# Epoch 440, loss and normalising constant 0.6718640923500061 1.0023497343063354
# Epoch 441, loss and normalising constant 0.6850851774215698 1.0023945569992065
# Epoch 442, loss and normalising constant 0.663159966468811 1.0024762153625488
# Epoch 443, loss and normalising constant 0.6642857789993286 1.0023784637451172
# Epoch 444, loss and normalising constant 0.6733613610267639 1.0023311376571655
# Epoch 445, loss and normalising constant 0.6821820139884949 1.0024594068527222
# Epoch 446, loss and normalising constant 0.6804790496826172 1.0024082660675049
# Epoch 447, loss and normalising constant 0.6637351512908936 1.002360463142395
# Epoch 448, loss and normalising constant 0.6707477569580078 1.002456784248352
# Epoch 449, loss and normalising constant 0.6639290452003479 1.0024585723876953
# Epoch 450, loss and normalising constant 0.6745864748954773 1.002346396446228
# Epoch 451, loss and normalising constant 0.6747199892997742 1.002454400062561
# Epoch 452, loss and normalising constant 0.6861572861671448 1.0024495124816895
# Epoch 453, loss and normalising constant 0.6703805923461914 1.0024052858352661
# Epoch 454, loss and normalising constant 0.6687790751457214 1.002507209777832
# Epoch 455, loss and normalising constant 0.6720432043075562 1.0025233030319214
# Epoch 456, loss and normalising constant 0.6896601915359497 1.002455472946167
# Epoch 457, loss and normalising constant 0.6792516708374023 1.0025371313095093
# Epoch 458, loss and normalising constant 0.669640064239502 1.0025439262390137
# Epoch 459, loss and normalising constant 0.6746050715446472 1.0024458169937134
# Epoch 460, loss and normalising constant 0.6794016361236572 1.0025092363357544
# Epoch 461, loss and normalising constant 0.6729364395141602 1.0025138854980469
# Epoch 462, loss and normalising constant 0.6896877884864807 1.0024183988571167
# Epoch 463, loss and normalising constant 0.6652730703353882 1.0025434494018555
# Epoch 464, loss and normalising constant 0.6795777082443237 1.0024917125701904
# Epoch 465, loss and normalising constant 0.6694614887237549 1.0024135112762451
# Epoch 466, loss and normalising constant 0.6814165115356445 1.002478837966919
# Epoch 467, loss and normalising constant 0.6718617677688599 1.00247061252594
# Epoch 468, loss and normalising constant 0.6739833354949951 1.0023962259292603
# Epoch 469, loss and normalising constant 0.6755038499832153 1.0024091005325317
# Epoch 470, loss and normalising constant 0.671001672744751 1.0024902820587158
# Epoch 471, loss and normalising constant 0.6728372573852539 1.0024579763412476
# Epoch 472, loss and normalising constant 0.6827034950256348 1.0024704933166504
# Epoch 473, loss and normalising constant 0.6782633066177368 1.002570629119873
# Epoch 474, loss and normalising constant 0.6810746192932129 1.0025384426116943
# Epoch 475, loss and normalising constant 0.6699709296226501 1.0025399923324585
# Epoch 476, loss and normalising constant 0.6714617013931274 1.0026147365570068
# Epoch 477, loss and normalising constant 0.6791543960571289 1.0025858879089355
# Epoch 478, loss and normalising constant 0.6810301542282104 1.0025266408920288
# Epoch 479, loss and normalising constant 0.6792023777961731 1.002591848373413
# Epoch 480, loss and normalising constant 0.6711575984954834 1.002586841583252
# Epoch 481, loss and normalising constant 0.673121988773346 1.002549648284912
# Epoch 482, loss and normalising constant 0.6712117195129395 1.0025794506072998
# Epoch 483, loss and normalising constant 0.6787793636322021 1.0025430917739868
# Epoch 484, loss and normalising constant 0.6740036606788635 1.0025522708892822
# Epoch 485, loss and normalising constant 0.6717361807823181 1.0025919675827026
# Epoch 486, loss and normalising constant 0.6743475198745728 1.002587914466858
# Epoch 487, loss and normalising constant 0.6761995553970337 1.0025228261947632
# Epoch 488, loss and normalising constant 0.6736652851104736 1.0025711059570312
# Epoch 489, loss and normalising constant 0.676236093044281 1.0025635957717896
# Epoch 490, loss and normalising constant 0.6847566366195679 1.0025273561477661
# Epoch 491, loss and normalising constant 0.6777925491333008 1.0026181936264038
# Epoch 492, loss and normalising constant 0.6783531308174133 1.002564549446106
# Epoch 493, loss and normalising constant 0.6773881912231445 1.0025403499603271
# Epoch 494, loss and normalising constant 0.6766433119773865 1.0026445388793945
# Epoch 495, loss and normalising constant 0.6830731630325317 1.0025935173034668
# Epoch 496, loss and normalising constant 0.6760897636413574 1.0025578737258911
# Epoch 497, loss and normalising constant 0.6743988990783691 1.0026750564575195
# Epoch 498, loss and normalising constant 0.6741310358047485 1.0025925636291504
# Epoch 499, loss and normalising constant 0.6843603253364563 1.0024936199188232

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import scipy.stats

# Set font size
font_size = 23

# Assuming ratio_copula is already trained
# Create a grid for plotting
x, y = np.meshgrid(np.linspace(-5, 5, 100), np.linspace(-5, 5, 100))
z = torch.tensor(np.column_stack((x.flatten(), y.flatten())))
gauss = scipy.stats.norm.pdf(x) * scipy.stats.norm.pdf(y)

# Get the ratio
r = ratio_copula(z.float()).detach().numpy()
Z = np.log(r.reshape(100, 100))

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5), gridspec_kw={'width_ratios': [0.85, 1, 1]})

# First subplot: scatter plot of u_1_mix and u_2_mix
axes[0].scatter(u_1_mix[:5000], u_2_mix[:5000], s=5)
axes[0].set_xlim(0, 1)
axes[0].set_ylim(0, 1)
axes[0].set_title(r'Copula samples $\mathcal{P}(\mathbf{x})$', fontsize=font_size)

# Second subplot: contour plot of r/(1+r) with scatter plots of data_gaussian[:100] and torch.randn(100,2)
r_transformed = r / (1 + r)
Z_transformed = r_transformed.reshape(100, 100)
contour = axes[1].contourf(x, y, Z_transformed, levels=20, cmap='coolwarm_r')

axes[1].scatter(torch.randn(100, 2)[:, 0], torch.randn(100, 2)[:, 1], color='red', edgecolors="k", s=70, label=r'Independent $\mathcal{N}(0,1)$', marker='o')
axes[1].scatter(data_gaussian[:100, 0], data_gaussian[:100, 1], color='blue', s=70, label='Copula samples', edgecolors="k", marker='o')
axes[1].set_xlim(-3, 3)
axes[1].set_ylim(-3, 3)
axes[1].set_title(r'Probabilistic classifier $h^*(\mathbf{x})$', fontsize=font_size)
axes[1].legend(fontsize=15)
fig.colorbar(contour, ax=axes[1])

# Third subplot: ratio model
contour = axes[2].contourf(scipy.stats.norm.cdf(x), scipy.stats.norm.cdf(y), Z, levels=30, cmap='inferno')
axes[2].set_xlim(0, 1)
axes[2].set_ylim(0, 1)
axes[2].set_title(r'Ratio copula $c\left(\mathcal{P}(\mathbf{x})\right)=\frac{h^*(\mathbf{x})}{1-h^*(\mathbf{x})}$', fontsize=font_size)
fig.colorbar(contour, ax=axes[2])

plt.tight_layout()
plt.savefig('ratio_copula_fig1.pdf', dpi=150)
